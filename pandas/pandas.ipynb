# %%
import pandas as pd

# %% [markdown]
# 1d series
# 2d dataframe
#
# data manipulation
# data cleaning
# data analysis
# data visulation

# %%
s = pd.Series([1,2,3,4,5])
print(s)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s2 = pd.Series({"maths":85,"physics":85,"chemistry":85,"english":85,"computer":85,})
print(s2)
# Out:
# maths        85
# physics      85
# chemistry    85
# english      85
# computer     85
# dtype: int64

# %%
s3 = pd.Series({"maths":85,"physics":85,"chemistry":85,"english":85,"computer":85,"gujarati":66,"biology":56})
print(s3)
print(s3.head())
print(s3.head(2))
print(s3.tail())
print(s3.tail(2))
print(s3.sample())
print(s3.info())
print(s3.shape)
print(s3.ndim)
# Out:
# maths        85
# physics      85
# chemistry    85
# english      85
# computer     85
# gujarati     66
# biology      56
# dtype: int64
# maths        85
# physics      85
# chemistry    85
# english      85
# computer     85
# dtype: int64
# maths      85
# physics    85
# dtype: int64
# chemistry    85
# english      85
# computer     85
# gujarati     66
# biology      56
# dtype: int64
# gujarati    66
# biology     56
# dtype: int64
# biology    56
# dtype: int64
# <class 'pandas.core.series.Series'>
# Index: 7 entries, maths to biology
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 7 non-null      int64
# dtypes: int64(1)
# memory usage: 112.0+ bytes
# None
# (7,)
# 1

# %%
s = pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])
print(s)
print(s['a'])
print("opss!!")
print(s[2])
print("opss!!")
print(s.loc['a'])
print(s.iloc[2])
print("opss!!")
print(s.at['a'])
print(s.iat[2])
print("opss!!")
print(s[['a','c']])
print(s['a':'c'])
print("opss!!")
print(s[s>2])
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64
# 1
# opss!!
# 3
# opss!!
# 1
# 3
# opss!!
# 1
# 3
# opss!!
# a    1
# c    3
# dtype: int64
# a    1
# b    2
# c    3
# dtype: int64
# opss!!
# c    3
# d    4
# e    5
# dtype: int64
# C:\Users\patel jeet\AppData\Local\Temp\ipykernel_12572\2536324181.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(s[2])
