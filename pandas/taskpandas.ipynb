# %%
import pandas as pd

# %%
# 1️⃣ Create a Series from [10, 20, 30, 40].

s = pd.Series([10,20,30,40])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
# 2️⃣ Create a Series with values [5, 6, 7] and index ["a","b","c"].
ss = pd.Series([5, 6, 7],index=["a","b","c"])
print(ss)
# Out:
# a    5
# b    6
# c    7
# dtype: int64

# %%
# 3️⃣ Create a Series from dictionary:

# {"Math": 85, "Sci": 90, "Eng": 88}

m = pd.Series(['85','90','88'],index=["maths","sci","eng"])
print(m)
# Out:
# maths    85
# sci      90
# eng      88
# dtype: object

# %%
# 4️⃣ Create a Series with scalar value 100 repeated for 5 indices.
s = pd.Series(100, index=['a','b','c','d','e'])
print(s)
# Out:
# a    100
# b    100
# c    100
# d    100
# e    100
# dtype: int64

# %%
# 5️⃣ Print first 3 values of a Series.
s.head(3)
# Out:
# a    100
# b    100
# c    100
# dtype: int64

# %%
# 6️⃣ Print last 2 values.
s.tail(2)
# Out:
# d    100
# e    100
# dtype: int64

# %%
# 7️⃣ Get the datatype of a Series.
s.dtype
# Out:
# dtype('int64')

# %%
# 8️⃣ Find number of elements in Series.
s.size
# Out:
# 5

# %%
# 9️⃣ Select value using label "b".
s['b']
# Out:
# np.int64(100)

# %%
# 🔟 Select value using position 2.
s.iloc[2]
# Out:
# np.int64(100)

# %%
# 1️⃣1️⃣ Slice first 4 elements.
s[:4]
# Out:
# a    100
# b    100
# c    100
# d    100
# dtype: int64

# %%
# 1️⃣2️⃣ Filter values greater than 50.
s[s > 50]
# Out:
# a    100
# b    100
# c    100
# d    100
# e    100
# dtype: int64

# %%
# 1️⃣3️⃣ Replace value 20 with 200.
s = pd.Series([10,20,30,40,50],index=['a','b','c','d','e'])
s.replace(20, 200)
# Out:
# a     10
# b    200
# c     30
# d     40
# e     50
# dtype: int64

# %%
# 1️⃣4️⃣ Rename index "a" to "alpha".
s.rename(index={'a': 'alpha'})
# Out:
# alpha    10
# b        20
# c        30
# d        40
# e        50
# dtype: int64

# %%
# 1️⃣5️⃣ Sort a Series by values.


s.sort_values()
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %% [markdown]
# # 🟡 MEDIUM LEVEL (16–30)

# %%
# 1️⃣6️⃣ Add 10 to every element in Series.
s2 = pd.Series([10, 20, 30, 40, 50], index=['a','b','c','d','e'])
s2 + 10
# Out:
# a    20
# b    30
# c    40
# d    50
# e    60
# dtype: int64

# %%
# 1️⃣7️⃣ Multiply two Series together.
s * s2
# Out:
# a     100
# b     400
# c     900
# d    1600
# e    2500
# dtype: int64

# %%
# 1️⃣8️⃣ Find sum of Series.
s2.sum()
# Out:
# np.int64(150)

# %%
# 1️⃣9️⃣ Find mean of values.
s2.mean()
# Out:
# np.float64(30.0)

# %%
# 2️⃣0️⃣ Find median.
s2.median()
# Out:
# 30.0

# %%
# 2️⃣1️⃣ Find standard deviation.
s2.std()
# Out:
# 15.811388300841896

# %%
# 2️⃣2️⃣ Count non-null values.
s3 = pd.Series([10, 20, 30, None, 50], index=['a','b','c','d','e'])
s3.notnull().sum()
# Out:
# np.int64(4)

# %%
# 2️⃣3️⃣ Replace missing values with 0.
s3.fillna(0)
# Out:
# a    10.0
# b    20.0
# c    30.0
# d     0.0
# e    50.0
# dtype: float64

# %%
# 2️⃣4️⃣ Drop missing values.
s4 = pd.Series([10, 20, 20, None, 50], index=['a','b','c','d','e'])
s4.dropna()
# Out:
# a    10.0
# b    20.0
# c    20.0
# e    50.0
# dtype: float64

# %%
# 2️⃣5️⃣ Get top 3 largest values.
s4.nlargest(3)
# Out:
# e    50.0
# b    20.0
# c    20.0
# dtype: float64

# %%
# 2️⃣6️⃣ Get 2 smallest values.
s4.nsmallest(2)
# Out:
# a    10.0
# b    20.0
# dtype: float64

# %%
# 2️⃣7️⃣ Apply lambda to square each value.
s4.apply(lambda x:x**2)
# Out:
# a     100.0
# b     400.0
# c     400.0
# d       NaN
# e    2500.0
# dtype: float64

# %%
# 2️⃣8️⃣ Count frequency of unique values.
s4.value_counts()
# Out:
# 20.0    2
# 10.0    1
# 50.0    1
# Name: count, dtype: int64

# %%
# 2️⃣9️⃣ Reindex Series to include new label "z".

# %%
# 3️⃣0️⃣ Calculate cumulative sum of Series.
